# %% [markdown]
# <a href="https://colab.research.google.com/github/justAnormlaguy/Inteligencia-Artificial/blob/main/Trabalho_Aula004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB

# Seu Dataset
data = [
    ['infantil','miopia','não','reduzida','nenhuma'],
    ['infantil','miopia','sim','normal','gelatinosa'],
    ['infantil','hipermetropia','não','normal','gelatinosa'],
    ['infantil','hipermetropia','sim','normal','dura'],
    ['adolescente','miopia','não','reduzida','gelatinosa'],
    ['adolescente','miopia','sim','reduzida','nenhuma'],
    ['adolescente','miopia','não','normal','dura'],
    ['adolescente','hipermetropia','não','reduzida','gelatinosa'],
    ['adolescente','hipermetropia','sim','normal','dura'],
    ['adulto','miopia','não','normal','gelatinosa'],
    ['adulto','miopia','sim','normal','dura'],
    ['adulto','miopia','sim','normal','gelatinosa'],
    ['adulto','hipermetropia','não','reduzida','nenhuma'],
    ['adulto','hipermetropia','sim','normal','gelatinosa'],
    ['adulto','hipermetropia','não','normal','gelatinosa']
]

# 1. Organizando em um DataFrame
colunas = ['Idade', 'Diagnostico', 'Astigmatismo', 'TaxaLacrimal', 'Lente']
df = pd.DataFrame(data, columns=colunas)

# Separando as variáveis previsoras (X) da variável alvo (y)
X = df.drop('Lente', axis=1)
y = df['Lente']

# 2. Convertendo as strings para valores numéricos
encoder = OrdinalEncoder()
X_encoded = encoder.fit_transform(X)

# 3. Criando e treinando o modelo Naive Bayes (alpha=1 representa a suavização de Laplace)
nb_classifier = CategoricalNB(alpha=1.0)
nb_classifier.fit(X_encoded, y)

# 4. Dados do novo paciente
paciente_novo = [['infantil', 'hipermetropia', 'não', 'reduzida']]

# Transformando os dados do paciente usando o mesmo encoder
paciente_encoded = encoder.transform(paciente_novo)

# 5. Realizando a previsão e obtendo as probabilidades
previsao = nb_classifier.predict(paciente_encoded)
probabilidades = nb_classifier.predict_proba(paciente_encoded)

# 6. Exibindo os resultados
print(f"=== PREVISÃO DO MODELO ===")
print(f"A lente recomendada para o paciente é: '{previsao[0]}'")

print("\n=== PROBABILIDADES NORMALIZADAS ===")
for classe, prob in zip(nb_classifier.classes_, probabilidades[0]):
    print(f"Classe '{classe}': {prob*100:.2f}%")
# Out:
# === PREVISÃO DO MODELO ===
# A lente recomendada para o paciente é: 'gelatinosa'
#
# === PROBABILIDADES NORMALIZADAS ===
# Classe 'dura': 7.56%
# Classe 'gelatinosa': 46.74%
# Classe 'nenhuma': 45.70%
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
